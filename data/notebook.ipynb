# %%
# import pandas
import pandas as pd

# read in the cities csv as dataframe
cities = pd.read_csv("../resources/cities.csv")

# checks that it was read in appropriately
cities.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Henties Bay -22.1160   14.2845     64.40        81           0        8.10
# 1    Coyhaique -45.5752  -72.0662     57.81        47          40        8.05
# 2       Noumea -22.2763  166.4572     78.01        99          22        5.57
# 3      Chicama  -7.8447  -79.1469     66.74        66          78       11.01
# 4  Kloulklubed   7.0419  134.2556     82.76        84          99       23.53
#
#   Country        Date
# 0     NaN  1649706196
# 1      CL  1649706001
# 2      NC  1649706197
# 3      PE  1649706646
# 4      PW  1649706646

# %%
# converts dataframe to html and prints the html code to copy
table_html = cities.to_html(index=False, col_space=75)
print(table_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 75px;">City</th>
#       <th style="min-width: 75px;">Lat</th>
#       <th style="min-width: 75px;">Lng</th>
#       <th style="min-width: 75px;">Max Temp</th>
#       <th style="min-width: 75px;">Humidity</th>
#       <th style="min-width: 75px;">Cloudiness</th>
#       <th style="min-width: 75px;">Wind Speed</th>
#       <th style="min-width: 75px;">Country</th>
#       <th style="min-width: 75px;">Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Henties Bay</td>
#       <td>-22.1160</td>
#       <td>14.2845</td>
#       <td>64.40</td>
#       <td>81</td>
#       <td>0</td>
#       <td>8.10</td>
#       <td>NaN</td>
#       <td>1649706196</td>
#     </tr>
#     <tr>
#       <td>Coyhaique</td>
#       <td>-45.5752</td>
#       <td>-72.0662</td>
#       <td>57.81</td>
#       <td>47</td>
#       <td>40</td>
#       <td>8.05</td>
# ...
